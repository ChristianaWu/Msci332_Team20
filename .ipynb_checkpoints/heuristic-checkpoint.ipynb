# %% [markdown]
# #### Heuristic Algorithm

# %%
import pprint
import random

#GREEDY ALGORTIHM   
def greedy_algo(A, D):
    PA_G = [1]
    OV_G = 0

    while(18 not in PA_G):
        current_node = PA_G[-1]
        adjacent_nodes = A[current_node]
        times = {}
        for (node, arc_time) in adjacent_nodes:
            times[arc_time + D[node]] = node
        min_total_time = min(times.keys())
        next_node = times[min_total_time]
        OV_G += min_total_time
        PA_G.append(next_node)
        
    print("Feasible Solution for Greedy Algorithm")
    print(f'Drone Path: {PA_G}')
    print(f'Objective value: {OV_G}\n')


#RANDOM ALGORITHM
def random_algo(A, D, num_rand_iters):
    min_OV = 10**6
    best_path = []

    for i in range(num_rand_iters):
        PA = [1]
        OV = 0

        while(18 not in PA):
            current_node = PA[-1]
            adjacent_nodes = A[current_node]
            next_node = random.choice(adjacent_nodes)
            OV += next_node[1] + D[next_node[0]]
            PA.append(next_node[0])
        # uncomment next line to see results of each iteration
        # print(f'iteration {i+1}: (obj val: {OV}) {PA}')
        if OV < min_OV:
            min_OV = OV
            best_path = PA

    print("Feasible Solution for Random Algorithm")
    print(f'Number of Random Iterations: {num_rand_iters}')
    print(f'Drone Path: {best_path}')
    print(f'Objective value: {min_OV}')

    
for n in range(1,5):
    
    test_file = f'test{n}.txt'
    
    arcs = [(1,2), (1,3), 
            (2,4), (2,5), (2, 6), 
            (3, 6), 
            (4, 5), (4, 9), 
            (5,8),
            (6, 7),(6, 8),
            (7, 8),(7, 11),
            (8, 9),(8, 10),(8, 11),
            (9, 12),(9, 13),
            (10,12),
            (11,12),(11,14),
            (12,13),(12,14),
            (13,15),
            (14,16),(14,17),
            (15,16),(15,18),
            (16,17),(16,18),
            (17,18)]

    # tij the time from node i to j
    A = {}
    D = {}

    for i in range(1,19):
        A[i] = []


    test_name = None
    num_rand_iters = 500

    if test_file:
        with open(test_file) as f:
            test_name = next(f)
            num_rand_iters = int(next(f).split(':')[-1])
            [next(f) for _ in range(2)]
            for i in range(31):
                arc_data = next(f).split()
                A[int(arc_data[0])].append((int(arc_data[-2]),int(arc_data[-1])))
            [next(f) for _ in range(2)]
            for _ in range(18):
                delay_data = next(f).split()
                D[int(delay_data[0])] = int(delay_data[-1])

    print('\n\n' + test_name)
    
    # run the third test a few times to try and find multiple optimal results
    if n == 3:
        for _ in range(2):
            greedy_algo(A, D)
            random_algo(A, D, num_rand_iters)
            print("\n")
    greedy_algo(A, D)
    random_algo(A, D, num_rand_iters)
# Out:
# Test 1: Greedy algo and random algo return the same result
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 2, 4, 9, 13, 15, 18]
# Objective value: 6
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 500
# Drone Path: [1, 2, 4, 9, 13, 15, 18]
# Objective value: 6
#
#
# Test 2: Same parameters as test 1 but number of random iterations is low
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 2, 4, 9, 13, 15, 18]
# Objective value: 6
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 5
# Drone Path: [1, 2, 4, 9, 13, 15, 18]
# Objective value: 6
#
#
# Test 3: Two minimum solutions (two paths are the same)
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 500
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 500
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 500
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 7
#
#
# Test 4: Random algo return better results than Greedy algo
#
# Feasible Solution for Greedy Algorithm
# Drone Path: [1, 3, 6, 8, 9, 13, 15, 18]
# Objective value: 32
#
# Feasible Solution for Random Algorithm
# Number of Random Iterations: 500
# Drone Path: [1, 3, 6, 7, 11, 14, 17, 18]
# Objective value: 9
